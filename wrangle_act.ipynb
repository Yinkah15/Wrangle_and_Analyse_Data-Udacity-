# %% [markdown]
# # Project: Wrangling and Analysis of  Data From 'WeRateDogs' Tweets

# %% [markdown]
# ## Outline
# * Introduction
# * Data Gathering
# * Assessing Data
# * Identifying Quality and Tidiness issues
# * Cleaning Data
# * Analysis and Visualization

# %% [markdown]
# ## Introduction

# %% [markdown]
# The project is carried out on tweets from a popular twitter page named 'WeRateDogs'.
# The tweets usually contain ratings of dogs over a scale of 10. More often than not, the scores given are above 10
# and this would not be adjusted for the project.
# Data for the project would be gathered from three sources, assesses , cleaned, analysed and visualised.
# Some insights would also be highlighted

# %% [markdown]
# ---

# %% [markdown]
# ## Data Gathering
# ### Data source 1
#
#
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
# Import relevant tools

import pandas as pd
import requests
import os
import numpy as np


# file has been previously downloaded and subequently uploaded unto the directory
# save as dataframe

twitter_archive = pd.read_csv('twitter-archive-enhanced.csv')
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# ### Data source 2
#
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
# creating new folder to download image_predictions file

folder_name = 'new_folder'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
# download image_predictions file using response

image_predictions = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(image_predictions)

response.content
with open(os.path.join(folder_name, image_predictions.split('/')[-1]), mode = 'wb') as file:
    file.write(response.content)

# %%
# Read into a datatframe

image_pred = pd.read_csv( 'new_folder/image-predictions.tsv', sep='\t')
image_pred
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %% [markdown]
# ### Data source 3
#
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = twitter_archive.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)

# %%
# The given 'tweet-json.txt' file was used

import json

with open("tweet-json.txt", 'r') as json_file:
    file = []
    for line in json_file:
        lines = line.replace('\n', '')
        file.append(lines)
lenght_of_line= len(file)
tweet_id= []
retweet_count= []
favorite_count= []
data = {'tweet_id': [], 'retweet_count' : [], 'favorite_count':[]}
for i in range(lenght_of_line):
    dictionary= json.loads(file[i])
    tweet_id.append(dictionary['id'])
    retweet_count.append(dictionary['retweet_count'])
    favorite_count.append(dictionary['favorite_count']) 
data.update({'tweet_id':tweet_id, 'retweet_count':retweet_count, 'favorite_count':favorite_count})
tweet= pd.DataFrame(data)

# Reading file into a dataframe
tweet.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %% [markdown]
# ----

# %% [markdown]
# ---

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# ### Assessing Twitter_archive

# %%
# TWITTER ARCHIVE


# Visual assessment
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
#checking 5 random tweets for visual assessment

twitter_archive.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2274  667455448082227200                    NaN                  NaN
# 2212  668587383441514497                    NaN                  NaN
# 340   832215909146226688                    NaN                  NaN
# 1565  688064179421470721                    NaN                  NaN
# 1180  719339463458033665                    NaN                  NaN
#
#                       timestamp  \
# 2274  2015-11-19 21:32:34 +0000
# 2212  2015-11-23 00:30:28 +0000
# 340   2017-02-16 13:11:49 +0000
# 1565  2016-01-15 18:24:18 +0000
# 1180  2016-04-11 01:41:07 +0000
#
#                                                  source  \
# 2274  <a href="http://twitter.com" rel="nofollow">Tw...
# 2212  <a href="http://vine.co" rel="nofollow">Vine -...
# 340   <a href="http://twitter.com/download/iphone" r...
# 1565  <a href="http://twitter.com/download/iphone" r...
# 1180  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
# Programmatic Assessment

twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
# Checking not_null values of 'in_reply_to_status_id'

# 'in_reply_to_status_id' column possibly means - tweet_id of replies
# 'in_reply_to_user_id' possibly means id of users who replied

twitter_archive[twitter_archive['in_reply_to_status_id'].notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# 149   863079547188785154           6.671522e+17         4.196984e+09
# 179   857214891891077121           8.571567e+17         1.806710e+08
# 184   856526610513747968           8.558181e+17         4.196984e+09
# 186   856288084350160898           8.562860e+17         2.792810e+08
# 188   855862651834028034           8.558616e+17         1.943518e+08
# 189   855860136149123072           8.558585e+17         1.361572e+07
# 218   850333567704068097           8.503288e+17         2.195506e+07
# 228   848213670039564288           8.482121e+17         4.196984e+09
# ...

# %%
# checking for null values in doggo
twitter_archive[twitter_archive['doggo'].isnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
# checking number of counts in doggo
twitter_archive['doggo'].value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
# checking value counts of name


twitter_archive['name'].value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Lucy         11
# Cooper       11
# Oliver       11
# Lola         10
# Tucker       10
# Penny        10
# Winston       9
# Bo            9
# Sadie         8
# the           8
# Daisy         7
# an            7
# Bailey        7
# Buddy         7
# Toby          7
# Oscar         6
# Scout         6
# Jax           6
# Dave          6
# Koda          6
# Stanley       6
# Milo          6
# Rusty         6
# Bella         6
# Jack          6
# Leo           6
# Sammy         5
#            ...
# Sky           1
# Willy         1
# Brudge        1
# Stella        1
# Harnold       1
# Bones         1
# Lilli         1
# Jaspers       1
# Chevy         1
# Halo          1
# Rhino         1
# Mairi         1
# Darla         1
# Claude        1
# Dex           1
# Chesney       1
# Crawford      1
# Rufio         1
# Darby         1
# Brooks        1
# Lupe          1
# Robin         1
# Antony        1
# Skittles      1
# ...

# %% [markdown]
# * Several names are filled with None, some are wrongly extracted

# %%
twitter_archive.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', 'None', 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver', 'Jim',
#        'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'such', 'Maya',
#        'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey', 'Lilly',
#        'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella', 'Grizzwald',
#        'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey', 'Gary', 'a',
#        'Elliot', 'Louis', 'Jesse', 'Romeo', 'Bailey', 'Duddles', 'Jack',
#        'Emmy', 'Steven', 'Beau', 'Snoopy', 'Shadow', 'Terrance', 'Aja',
#        'Penny', 'Dante', 'Nelly', 'Ginger', 'Benedict', 'Venti', 'Goose',
#        'Nugget', 'Cash', 'Coco', 'Jed', 'Sebastian', 'Walter', 'Sierra',
#        'Monkey', 'Harry', 'Kody', 'Lassie', 'Rover', 'Napolean', 'Dawn',
#        'Boomer', 'Cody', 'Rumble', 'Clifford', 'quite', 'Dewey', 'Scout',
#        'Gizmo', 'Cooper', 'Harold', 'Shikha', 'Jamesy', 'Lili', 'Sammy',
# ...

# %% [markdown]
# * Most dog names beginning with lowercase seem wrong

# %%
twitter_archive[twitter_archive.name.str.islower()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 22    887517139158093824                    NaN                  NaN
# 56    881536004380872706                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# 169   859196978902773760                    NaN                  NaN
# 193   855459453768019968                    NaN                  NaN
# 335   832645525019123713                    NaN                  NaN
# 369   828650029636317184                    NaN                  NaN
# 542   806219024703037440                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 682   788552643979468800                    NaN                  NaN
# 759   778396591732486144                    NaN                  NaN
# 773   776249906839351296                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# ...

# %% [markdown]
# * Dog names beginning in lower case are not correct

# %%
# checking sum of duplicated twitter_id

sum(twitter_archive.tweet_id.duplicated())
# Out:
# 0

# %% [markdown]
# * No duplicated twitter_ids

# %% [markdown]
# ### Assessing image_predictions

# %%
# ASSESSING IMAGE_PREDICTIONS

# %%
image_pred.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
image_pred.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 700   684800227459624960  https://pbs.twimg.com/media/CYDmK7ZVAAI_ylL.jpg
# 1107  723673163800948736  https://pbs.twimg.com/media/CgsA5eFWgAAu0qn.jpg
# 960   705786532653883392  https://pbs.twimg.com/media/Cct1G6vVAAI9ZjF.jpg
# 1047  713177543487135744  https://pbs.twimg.com/media/CeW3MWMWQAEOMbq.jpg
# 147   668631377374486528  https://pbs.twimg.com/media/CUd0sSvWsAA85wO.jpg
#
#       img_num                   p1   p1_conf  p1_dog                  p2  \
# 700         1  miniature_schnauzer  0.294457    True     Norfolk_terrier
# 1107        1     golden_retriever  0.839390    True  Labrador_retriever
# 960         1             web_site  0.550294   False  Labrador_retriever
# 1047        1              whippet  0.734244    True             basenji
# 147         1  miniature_schnauzer  0.904549    True  Australian_terrier
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# ...

# %%
image_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_pred.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %% [markdown]
# ### Assessing twitter json file

# %%
# ASSESSING TWITTER JSON FILE

# %%
tweet.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %%
tweet.sample(5)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 736   780858289093574656           2328            8033
# 652   792050063153438720           2088            8029
# 2341  666073100786774016            174             335
# 1782  677662372920729601           1101            2134
# 875   760893934457552897           1104            4228

# %%
tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %%
tweet.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %%
tweet.retweet_count.sort_values()
# Out:
# 290         0
# 1293        2
# 273         3
# 341         3
# 112         3
# 29          4
# 1078        6
# 54          7
# 426        10
# 63         10
# 2296       14
# 2337       16
# 185        17
# 1521       19
# 178        20
# 2317       23
# 211        23
# 2187       25
# 1235       26
# 187        27
# 408        31
# 100        31
# 610        32
# 2258       34
# 2222       34
# 2257       37
# 2335       37
# 284        38
# 883        38
# 965        39
#         ...
# 309     24013
# 528     24069
# 449     24069
# 1075    24319
# 888     24319
# 653     24514
# 1623    24514
# 117     25661
# 168     25661
# 114     27680
# 623     27728
# 1764    30742
# 458     31314
# 302     31314
# 1828    31989
# 134     32883
# 131     32883
# 868     33421
# 164     33421
# 536     37911
# 154     37911
# 445     42228
# 448     42228
# 65      45849
# 412     48265
# 816     52360
# 1077    52360
# 259     56625
# 533     56625
# 1037    79515
# ...

# %% [markdown]
# * tweet with index 1037 has the highest retweet count of 79515

# %%
tweet.favorite_count.sort_values()
# Out:
# 484          0
# 585          0
# 164          0
# 588          0
# 909          0
# 170          0
# 676          0
# 670          0
# 385          0
# 593          0
# 381          0
# 594          0
# 595          0
# 681          0
# 179          0
# 181          0
# 597          0
# 598          0
# 184          0
# 599          0
# 600          0
# 924          0
# 601          0
# 193          0
# 194          0
# 668          0
# 602          0
# 596          0
# 159          0
# 158          0
#          ...
# 552      49774
# 447      49960
# 55       50199
# 53       51522
# 135      54720
# 868      55016
# 122      55098
# 623      55683
# 394      56413
# 7        56848
# 458      57622
# 364      58302
# 1764     61794
# 153      66437
# 1828     67100
# 37       68152
# 22       69871
# 76       71144
# 355      73397
# 41       74423
# 1077     75163
# 168      75193
# 536      75639
# 114      85011
# 448      95450
# 134     106827
# 533     107015
# ...

# %% [markdown]
# * tweet with index 412 has the highest favorite count - 132810

# %% [markdown]
# ### Quick Reassessment of the three dataframes

# %%
twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
image_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Quality issues
#
# 1. Datatype issues: tweet_id column is stored as integer in 'twitter_archive', 'image_prediction' and 'tweet' dataframes also timestamp column in 'twitter_archive' is stored as string datatype
#
# 2. Wrong dog names, the wrong dog names are noted to all be in lowercase
#
# 3. Rows with replies and rows with retweets
#
# 4. Irrelevant columns: 'in_reply_to_status_id', 'in_reply_to_user_id','retweeted_status_id' , 'retweeted_status_user_id' and 'retweeted_status_timestamp' contain replies and retweet and are not relevant to analysis
#
# 5. Some rating_denominators are not 10
#
# 6. Unclear column names description in image_pred dataframe
#
# 7. Some dog rating_numerators were wrongly extracted
#
# 8. From image_pred dataframe, the three image predictions (p1_dog, p2_dog and p3_dog) of some tweets were not dogs

# %% [markdown]
# ### Tidiness issues
#
# 1. Dog stage variable in four columns
# 2. All the data should be on one table

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Cleaning Data

# %%
# Make copies of original pieces of data
twitter_archive_clean = twitter_archive.copy()

# %%
image_pred_clean = image_pred.copy()

# %%
tweet_clean = tweet.copy()

# %% [markdown]
# ### Quality Issues :

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define:
#
# Datatype issues:
# change tweet_id column from integer datatype in 'twitter_archive', 'image_prediction' and 'tweet' dataframes to string
# change timestamp column in 'twitter_archive' from string datatype to datetime

# %% [markdown]
# #### Code

# %%
# changing tweet_id to string ,and timestamp to datetime in twitter_archive dataframe

twitter_archive_clean.tweet_id = twitter_archive_clean.tweet_id.astype(str)
twitter_archive_clean['timestamp'] = pd.to_datetime(twitter_archive_clean['timestamp'])

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null object
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# #### Code

# %%
# Changing tweet_id to string in image_pred dataframe

image_pred_clean.tweet_id = image_pred_clean.tweet_id.astype(str)

# %% [markdown]
# #### Test

# %%
image_pred_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null object
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# #### Code

# %%
# Changing tweet_id to string in tweet dataframe

tweet_clean.tweet_id = image_pred_clean.tweet_id.astype(str)

# %% [markdown]
# #### Test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2075 non-null object
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 55.2+ KB

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define:
# Wrong dog names, the wrong dog names are noted to all be in lowercase
# Change dog names in lower case to 'None'

# %% [markdown]
# #### Code

# %%
twitter_archive_clean[twitter_archive_clean.name.str.islower()].head()
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 22   887517139158093824                    NaN                  NaN
# 56   881536004380872706                    NaN                  NaN
# 118  869988702071779329                    NaN                  NaN
# 169  859196978902773760                    NaN                  NaN
# 193  855459453768019968                    NaN                  NaN
#
#               timestamp                                             source  \
# 22  2017-07-19 03:39:09  <a href="http://twitter.com/download/iphone" r...
# 56  2017-07-02 15:32:16  <a href="http://twitter.com/download/iphone" r...
# 118 2017-05-31 18:47:24  <a href="http://twitter.com/download/iphone" r...
# 169 2017-05-02 00:04:57  <a href="http://twitter.com/download/iphone" r...
# 193 2017-04-21 16:33:22  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# ...

# %%
twitter_archive_clean.name.str.islower().value_counts()
# Out:
# False    2247
# True      109
# Name: name, dtype: int64

# %%
twitter_archive_clean.name.value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Lucy         11
# Cooper       11
# Oliver       11
# Lola         10
# Tucker       10
# Penny        10
# Winston       9
# Bo            9
# Sadie         8
# the           8
# Daisy         7
# an            7
# Bailey        7
# Buddy         7
# Toby          7
# Oscar         6
# Scout         6
# Jax           6
# Dave          6
# Koda          6
# Stanley       6
# Milo          6
# Rusty         6
# Bella         6
# Jack          6
# Leo           6
# Sammy         5
#            ...
# Sky           1
# Willy         1
# Brudge        1
# Stella        1
# Harnold       1
# Bones         1
# Lilli         1
# Jaspers       1
# Chevy         1
# Halo          1
# Rhino         1
# Mairi         1
# Darla         1
# Claude        1
# Dex           1
# Chesney       1
# Crawford      1
# Rufio         1
# Darby         1
# Brooks        1
# Lupe          1
# Robin         1
# Antony        1
# Skittles      1
# ...

# %%
# create a dataframe for names to be replaced

replace_name = twitter_archive_clean[twitter_archive_clean.name.str.islower()]

# %%
# replace names with 'None'

twitter_archive_clean.name.replace( [replace_name.name] , 'None', inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.name.value_counts()
# Out:
# None        854
# Charlie      12
# Cooper       11
# Oliver       11
# Lucy         11
# Lola         10
# Tucker       10
# Penny        10
# Bo            9
# Winston       9
# Sadie         8
# Buddy         7
# Toby          7
# Bailey        7
# Daisy         7
# Oscar         6
# Jack          6
# Milo          6
# Jax           6
# Leo           6
# Stanley       6
# Scout         6
# Dave          6
# Bella         6
# Rusty         6
# Koda          6
# Alfie         5
# Phil          5
# George        5
# Chester       5
#            ...
# Sky           1
# Willy         1
# Brudge        1
# Stella        1
# Harnold       1
# Evy           1
# Bones         1
# Mairi         1
# Robin         1
# Darla         1
# Claude        1
# Dex           1
# Chesney       1
# Crawford      1
# Rufio         1
# Chevy         1
# Darby         1
# Lupe          1
# Comet         1
# Lilli         1
# Antony        1
# Skittles      1
# Gerbald       1
# Colin         1
# ...

# %%
twitter_archive_clean.name.str.islower().value_counts()
# Out:
# False    2356
# Name: name, dtype: int64

# %% [markdown]
# ### Issue #3:

# %% [markdown]
# #### Define
#
# * rows with replies and retweets are to be removed

# %% [markdown]
# #### Code

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null object
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# * 'in_reply_to_status_id' has 78 non-null values while 'retweeted_status_user_id' has 181 non_null values

# %%
twitter_archive_clean.retweeted_status_id.notnull().sum()
# Out:
# 181

# %%
twitter_archive_clean.in_reply_to_status_id.notnull().sum()
# Out:
# 78

# %%
twitter_archive_clean[(twitter_archive_clean.retweeted_status_id.notnull()) | (twitter_archive.in_reply_to_status_id.notnull())]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# 74    878316110768087041                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 91    874434818259525634                    NaN                  NaN
# 95    873697596434513921                    NaN                  NaN
# 97    873337748698140672                    NaN                  NaN
# ...

# %%
drop_retweets_n_replies = twitter_archive_clean[(twitter_archive_clean.retweeted_status_id.notnull()) | (twitter_archive_clean.in_reply_to_status_id.notnull())]

# %%
twitter_archive_clean.drop(drop_retweets_n_replies.index, axis=0, inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2097 non-null object
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     2097 non-null datetime64[ns]
# source                        2097 non-null object
# text                          2097 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2094 non-null object
# rating_numerator              2097 non-null int64
# rating_denominator            2097 non-null int64
# name                          2097 non-null object
# doggo                         2097 non-null object
# floofer                       2097 non-null object
# pupper                        2097 non-null object
# ...

# %% [markdown]
# ### Issue #4:

# %% [markdown]
# #### Define
#
# * Remove irrelevant columns
# * Irrelevant columns: 'in_reply_to_status_id', 'in_reply_to_user_id','retweeted_status_id' , 'retweeted_status_user_id' and 'retweeted_status_timestamp' contain replies and retweet and are not relevant to analysis

# %% [markdown]
# #### Code

# %%
twitter_archive_clean.drop([ 'in_reply_to_status_id', 'in_reply_to_user_id','retweeted_status_id' , 'retweeted_status_user_id', 'retweeted_status_timestamp'], axis=1 , inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2097 non-null object
# timestamp             2097 non-null datetime64[ns]
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# doggo                 2097 non-null object
# floofer               2097 non-null object
# pupper                2097 non-null object
# puppo                 2097 non-null object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Issue #5:

# %% [markdown]
# #### Define
#
# * Change all rating denominators to 10
# * Some rating_denominators are not 10

# %% [markdown]
# #### Code

# %%
# Check all denominators

twitter_archive_clean.groupby('rating_denominator')['tweet_id'].count()
# Out:
# rating_denominator
# 2         1
# 7         1
# 10     2080
# 11        2
# 20        1
# 40        1
# 50        3
# 70        1
# 80        2
# 90        1
# 110       1
# 120       1
# 150       1
# 170       1
# Name: tweet_id, dtype: int64

# %%
# check rows where denominators are not 10

twitter_archive_clean[twitter_archive_clean.rating_denominator != 10].head()
# Out:
#                 tweet_id           timestamp  \
# 433   820690176645140481 2017-01-15 17:52:40
# 516   810984652412424192 2016-12-19 23:06:23
# 902   758467244762497024 2016-07-28 01:00:57
# 1068  740373189193256964 2016-06-08 02:41:38
# 1120  731156023742988288 2016-05-13 16:15:54
#
#                                                  source  \
# 433   <a href="http://twitter.com/download/iphone" r...
# 516   <a href="http://twitter.com/download/iphone" r...
# 902   <a href="http://twitter.com/download/iphone" r...
# 1068  <a href="http://twitter.com/download/iphone" r...
# 1120  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 433   The floofs have been released I repeat the flo...
# 516   Meet Sam. She smiles 24/7 &amp; secretly aspir...
# 902   Why does this never happen at my front door......
# 1068  After so many requests, this is Bretagne. She ...
# 1120  Say hello to this unbelievably well behaved sq...
#
# ...

# %%
# Replacing denominators 

twitter_archive_clean.rating_denominator.replace([twitter_archive_clean.rating_denominator], 10, inplace=True) # works

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.groupby('rating_denominator')['tweet_id'].count()
# Out:
# rating_denominator
# 10    2097
# Name: tweet_id, dtype: int64

# %% [markdown]
# ### Issue #6:

# %% [markdown]
# #### Define
#
# * Properly name columns in image_pred dataframe
# * Unclear column names description in image_pred dataframe

# %% [markdown]
# #### Code

# %%
image_pred_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null object
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
image_pred_clean.rename(columns = {'p1':'first_prediction', 'p1_conf':'first_prediction_conf','p1_dog':'first_prediction_dog',
                              'p2':'second_prediction','p2_conf':'second_prediction_conf','p2_dog':'second_prediction_dog','p3':'third_prediction','p3_conf':'third_prediction_conf','p3_dog':'third_prediction_dog',}, inplace = True)

# %% [markdown]
# #### Test

# %%
image_pred_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id                  2075 non-null object
# jpg_url                   2075 non-null object
# img_num                   2075 non-null int64
# first_prediction          2075 non-null object
# first_prediction_conf     2075 non-null float64
# first_prediction_dog      2075 non-null bool
# second_prediction         2075 non-null object
# second_prediction_conf    2075 non-null float64
# second_prediction_dog     2075 non-null bool
# third_prediction          2075 non-null object
# third_prediction_conf     2075 non-null float64
# third_prediction_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# ### Issue #7:

# %% [markdown]
# #### Define
#
# * Properly extract rating_numerators
# * Some dog rating_numerators were wrongly extracted

# %% [markdown]
# #### Code

# %%
# Use regex to extract rating_ numerators from the tweet texts

twitter_archive_clean[twitter_archive_clean.text.str.contains(r"(\d+\.\d*\/\d+)")][['text','rating_numerator']]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                    text  rating_numerator
# 45    This is Bella. She hopes her smile made you sm...                 5
# 695   This is Logan, the Chow who lived. He solemnly...                75
# 763   This is Sophie. She's a Jubilant Bush Pupper. ...                27
# 1712  Here we have uncovered an entire battalion of ...                26

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.tail(3)
# Out:
#                 tweet_id           timestamp  \
# 2353  666033412701032449 2015-11-15 23:21:54
# 2354  666029285002620928 2015-11-15 23:05:30
# 2355  666020888022790149 2015-11-15 22:32:08
#
#                                                  source  \
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 2353  Here is a very happy pup. Big fan of well-main...
# 2354  This is a western brown Mitsubishi terrier. Up...
# 2355  Here we have a Japanese Irish Setter. Lost eye...
#
#                                           expanded_urls  rating_numerator  \
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
# ...

# %% [markdown]
# ### Issue #8:

# %% [markdown]
# #### Define
#
# * Remove rows of image predictions where the first, second and third predictions were false
# * From image_pred dataframe, the three image predictions (p1_dog, p2_dog and p3_dog) of some tweets were not dogs

# %% [markdown]
# #### Code

# %%
image_pred_clean.sample(5)
# Out:
#                 tweet_id                                            jpg_url  \
# 964   706166467411222528    https://pbs.twimg.com/media/CczOp_OWoAAo5zR.jpg
# 1632  805826884734976000  https://pbs.twimg.com/ext_tw_video_thumb/80582...
# 1772  827933404142436356    https://pbs.twimg.com/media/C31pCN4UcAAOLNH.jpg
# 1477  780543529827336192    https://pbs.twimg.com/media/CtUMLzRXgAAbZK5.jpg
# 1522  788070120937619456    https://pbs.twimg.com/media/Co-hmcYXYAASkiG.jpg
#
#       img_num  first_prediction  first_prediction_conf  first_prediction_dog  \
# 964         1           Samoyed               0.430418                  True
# 1632        1    Siberian_husky               0.248926                  True
# 1772        2   German_shepherd               0.806115                  True
# 1477        1  golden_retriever               0.628312                  True
# 1522        1  golden_retriever               0.735163                  True
#
# ...

# %%
# Show rows with all predictions as 'False'

image_pred_clean[(image_pred_clean.first_prediction_dog == False) & (image_pred_clean.second_prediction_dog == False) & (image_pred_clean.third_prediction_dog == False)]
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 25    666362758909284353    https://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# 29    666411507551481857    https://pbs.twimg.com/media/CT-RugiWIAELEaq.jpg
# 45    666786068205871104    https://pbs.twimg.com/media/CUDmZIkWcAAIPPe.jpg
# 50    666837028449972224    https://pbs.twimg.com/media/CUEUva1WsAA2jPb.jpg
# 51    666983947667116034    https://pbs.twimg.com/media/CUGaXDhW4AY9JUH.jpg
# 53    667012601033924608    https://pbs.twimg.com/media/CUG0bC0U8AAw2su.jpg
# 56    667065535570550784    https://pbs.twimg.com/media/CUHkkJpXIAA2w3n.jpg
# ...

# %%
image_pred_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id                  2075 non-null object
# jpg_url                   2075 non-null object
# img_num                   2075 non-null int64
# first_prediction          2075 non-null object
# first_prediction_conf     2075 non-null float64
# first_prediction_dog      2075 non-null bool
# second_prediction         2075 non-null object
# second_prediction_conf    2075 non-null float64
# second_prediction_dog     2075 non-null bool
# third_prediction          2075 non-null object
# third_prediction_conf     2075 non-null float64
# third_prediction_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
# Create a dataframe for predictions that are all false

all_false_pred= image_pred_clean[(image_pred_clean.first_prediction_dog == False) & (image_pred_clean.second_prediction_dog == False) & (image_pred_clean.third_prediction_dog == False)]

# %%
# Drop rows

image_pred_clean.drop( all_false_pred.index, axis=0, inplace=True)

# %% [markdown]
# #### Test

# %%
image_pred_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2073
# Data columns (total 12 columns):
# tweet_id                  1751 non-null object
# jpg_url                   1751 non-null object
# img_num                   1751 non-null int64
# first_prediction          1751 non-null object
# first_prediction_conf     1751 non-null float64
# first_prediction_dog      1751 non-null bool
# second_prediction         1751 non-null object
# second_prediction_conf    1751 non-null float64
# second_prediction_dog     1751 non-null bool
# third_prediction          1751 non-null object
# third_prediction_conf     1751 non-null float64
# third_prediction_dog      1751 non-null bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 141.9+ KB

# %% [markdown]
# ---

# %% [markdown]
# ### Tidiness Issues :

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define
#
# Merge the 4 dog stage columns into one, named 'dog_stage'

# %% [markdown]
# #### Code

# %%
# from twitter_archive_clean dataframe, use loop to replace 'None' with an empty string

stage= ['doggo', 'pupper', 'floofer', 'puppo']
for i in stage:
    twitter_archive_clean[i]= twitter_archive_clean[i].replace('None', '')

# %%
# Merging the columns

twitter_archive_clean['dog_stage']= twitter_archive_clean.doggo+ twitter_archive_clean.floofer + twitter_archive_clean.pupper+ twitter_archive_clean.puppo

# %%
# test

assert "dog_stage" in twitter_archive_clean

# %%
# correcting invalid dog stages

twitter_archive_clean.loc[twitter_archive_clean.dog_stage == 'doggofloofer', 'dog_stage'] = 'floofer'
twitter_archive_clean.loc[twitter_archive_clean.dog_stage == 'doggopupper', 'dog_stage'] = 'pupper'
twitter_archive_clean.loc[twitter_archive_clean.dog_stage == 'doggopuppo', 'dog_stage'] = 'puppo'

# %%
import numpy as np

# replacing empty strings with pandas NaN

twitter_archive_clean.loc[twitter_archive_clean.dog_stage == '', 'dog_stage'] = np.nan

# %%
# dropping columns

twitter_archive_clean.drop(['doggo', 'floofer', 'pupper', 'puppo'], axis = 1, inplace = True)

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.sample(5)
# Out:
#                 tweet_id           timestamp  \
# 2041  671542985629241344 2015-12-01 04:14:59
# 1449  696100768806522880 2016-02-06 22:38:50
# 1820  676588346097852417 2015-12-15 02:23:26
# 92    874296783580663808 2017-06-12 16:06:11
# 722   783085703974514689 2016-10-03 23:25:55
#
#                                                  source  \
# 2041  <a href="http://twitter.com/download/iphone" r...
# 1449  <a href="http://vine.co" rel="nofollow">Vine -...
# 1820  <a href="http://twitter.com/download/iphone" r...
# 92    <a href="http://twitter.com/download/iphone" r...
# 722   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 2041  This is JD (stands for "just dog"). He's like ...
# 1449  This poor pupper has been stuck in a vortex si...
# 1820  This is Bubbles. He kinda resembles a fish. Al...
# 92    This is Jed. He may be the fanciest pupper in ...
# 722   This is Earl. He can't catch. Did his best tho...
#
# ...

# %%
twitter_archive_clean.groupby('dog_stage')['tweet_id'].count()
# Out:
# dog_stage
# doggo       72
# floofer     10
# pupper     230
# puppo       24
# Name: tweet_id, dtype: int64

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define
# - Convert the three dataframes to one master dataframe
# - Merge twitter_archive_clean, image_pred_clean and tweet_clean dataframes to form the master dataset, joining on 'tweet_id'

# %% [markdown]
# #### Code

# %%
twitter_archive_clean = pd.merge(pd.merge(twitter_archive_clean, image_pred_clean,on=['tweet_id'], how='left'), tweet_clean, on=['tweet_id'], how='left')

# %% [markdown]
# #### Test

# %%
twitter_archive_clean.sample(3)
# Out:
#                 tweet_id           timestamp  \
# 987   716080869887381504 2016-04-02 01:52:38
# 1773  671891728106971137 2015-12-02 03:20:45
# 707   757611664640446465 2016-07-25 16:21:11
#
#                                                  source  \
# 987   <a href="http://twitter.com/download/iphone" r...
# 1773  <a href="http://twitter.com/download/iphone" r...
# 707   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 987   Here's a super majestic doggo and a sunset 11/...
# 1773  This is Mojo. Apparently he's too cute for a s...
# 707   This is Cooper. He tries to come across as fei...
#
#                                           expanded_urls  rating_numerator  \
# 987   https://twitter.com/dog_rates/status/716080869...                11
# 1773  https://twitter.com/dog_rates/status/671891728...                11
# 707   https://twitter.com/dog_rates/status/757611664...                12
#
# ...

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 22 columns):
# tweet_id                  2097 non-null object
# timestamp                 2097 non-null datetime64[ns]
# source                    2097 non-null object
# text                      2097 non-null object
# expanded_urls             2094 non-null object
# rating_numerator          2097 non-null int64
# rating_denominator        2097 non-null int64
# name                      2097 non-null object
# dog_stage                 336 non-null object
# jpg_url                   1666 non-null object
# img_num                   1666 non-null float64
# first_prediction          1666 non-null object
# first_prediction_conf     1666 non-null float64
# first_prediction_dog      1666 non-null object
# second_prediction         1666 non-null object
# second_prediction_conf    1666 non-null float64
# second_prediction_dog     1666 non-null object
# ...

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Storing Data
# Gathered, assessed, and cleaned master dataset is saved to a CSV file named "twitter_archive_master.csv".

# %%
twitter_archive_clean.to_csv('twitter_archive_master.csv', index= False)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Analyzing and Visualizing Data

# %%
twitter_archive_clean.sample(2)
# Out:
#                 tweet_id           timestamp  \
# 1439  682088079302213632 2015-12-30 06:37:25
# 694   759099523532779520 2016-07-29 18:53:24
#
#                                                  source  \
# 1439  <a href="http://vine.co" rel="nofollow">Vine -...
# 694   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 1439  I'm not sure what this dog is doing but it's p...
# 694   Meet Toby. He has a drinking problem. Inflatab...
#
#                                           expanded_urls  rating_numerator  \
# 1439                      https://vine.co/v/iqMjlxULzbn                12
# 694   https://twitter.com/dog_rates/status/759099523...                 7
#
#       rating_denominator  name dog_stage  \
# 1439                  10  None       NaN
# 694                   10  Toby       NaN
#
#                                               jpg_url      ...        \
# ...

# %%
twitter_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 22 columns):
# tweet_id                  2097 non-null object
# timestamp                 2097 non-null datetime64[ns]
# source                    2097 non-null object
# text                      2097 non-null object
# expanded_urls             2094 non-null object
# rating_numerator          2097 non-null int64
# rating_denominator        2097 non-null int64
# name                      2097 non-null object
# dog_stage                 336 non-null object
# jpg_url                   1666 non-null object
# img_num                   1666 non-null float64
# first_prediction          1666 non-null object
# first_prediction_conf     1666 non-null float64
# first_prediction_dog      1666 non-null object
# second_prediction         1666 non-null object
# second_prediction_conf    1666 non-null float64
# second_prediction_dog     1666 non-null object
# ...

# %% [markdown]
# ---

# %% [markdown]
# ----
#    ## Analyze

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #### Twitter_archive_clean Analysis

# %%
# Plot bar chart showing top 10 rating values


twitter_archive_clean.rating_numerator.head(10).sort_values(ascending=False).plot(kind='bar', figsize=(25,20))
plt.title("Top 10 ratings", fontsize=50)
plt.xlabel("Index", fontsize=30 )
plt.ylabel("Ratings", fontsize=30)
plt.xticks(fontsize= 20, rotation=0);
plt.yticks(fontsize= 20);

# %% [markdown]
# * This showed that the highest rating is 14/10

# %%
# Checking the dog stages
twitter_archive_clean.groupby('dog_stage')['tweet_id'].count()
# Out:
# dog_stage
# doggo       72
# floofer     10
# pupper     230
# puppo       24
# Name: tweet_id, dtype: int64

# %%
# Pie chart showing the percentage of dog stages 

twitter_archive_clean.groupby('dog_stage')['tweet_id'].count().plot(kind='pie', figsize=(15,15), autopct='%1.1f%%', legend=0, textprops={'fontsize': 20})
plt.title("Dog stages", fontsize=30)
# Out:
# Text(0.5,1,'Dog stages')

# %% [markdown]
# * Of the tweets with dog stages, the pupper stage constituted about two-thirds

# %%
# Dog with most retweeted tweet

#twitter_archive_clean.groupby(['name','retweet_count']).count().sort_values('retweet_count', ascending=False)


twitter_archive_clean[[ 'name', 'retweet_count']].sort_values('retweet_count', ascending=False).head(10)
# Out:
#           name  retweet_count
# 1569      None        56625.0
# 1839      None        56625.0
# 1264      None        52360.0
# 976       None        52360.0
# 1687      Obie        48265.0
# 2031  Clarence        45849.0
# 1653      None        42228.0
# 1650   Patrick        42228.0
# 1565      None        37911.0
# 1943     Kevon        37911.0

# %% [markdown]
# * Of the tweets with dog names, the dog with name Obie has the most retweet with 48265 retweets

# %%
# Dog with highest favorite count

twitter_archive_clean[[ 'name', 'favorite_count']].sort_values('favorite_count', ascending=False).head(10)
# Out:
#           name  favorite_count
# 1687      Obie        132810.0
# 2031  Clarence        107956.0
# 1569      None        107015.0
# 1964      None        106827.0
# 1650   Patrick         95450.0
# 1984    Jiminy         85011.0
# 1565      None         75639.0
# 1929      None         75193.0
# 976       None         75163.0
# 2055      None         74423.0

# %% [markdown]
# * Obie's tweet seems to have the highest favourite count with 132810 favorite counts

# %% [markdown]
# #### Image_predictions Analysis

# %%
image_pred_clean.head(3)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
#
#    img_num        first_prediction  first_prediction_conf  \
# 0        1  Welsh_springer_spaniel               0.465074
# 1        1                 redbone               0.506826
# 2        1         German_shepherd               0.596461
#
#    first_prediction_dog   second_prediction  second_prediction_conf  \
# 0                  True              collie                0.156665
# 1                  True  miniature_pinscher                0.074192
# 2                  True            malinois                0.138584
#
#    second_prediction_dog     third_prediction  third_prediction_conf  \
# 0                   True    Shetland_sheepdog               0.061428
# ...

# %%
image_pred_clean.groupby(['first_prediction_dog']).tweet_id.count()
# Out:
# first_prediction_dog
# False     219
# True     1532
# Name: tweet_id, dtype: int64

# %%
image_pred_clean.groupby(['first_prediction_dog']).tweet_id.count().plot(kind='pie', figsize=(15,15), autopct='%1.1f%%', textprops={'fontsize': 20})
plt.title("Image Predictions", fontsize=30)
# Out:
# Text(0.5,1,'Image Predictions')

# %% [markdown]
# * Over three-fourths of the first image predictions by the algorithm turned out to be dogs

# %%
twitter_archive_clean[twitter_archive_clean.name == 'Obie']
# Out:
#                 tweet_id           timestamp  \
# 1687  673919437611909120 2015-12-07 17:38:09
#
#                                                  source  \
# 1687  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 1687  This is Obie. He is on guard watching for evil...
#
#                                           expanded_urls  rating_numerator  \
# 1687  https://twitter.com/dog_rates/status/673919437...                11
#
#       rating_denominator  name dog_stage  \
# 1687                  10  Obie    pupper
#
#                                               jpg_url      ...        \
# 1687  https://pbs.twimg.com/media/CVo-JuMWwAAet6F.jpg      ...
#
#       first_prediction_conf first_prediction_dog  second_prediction  \
# 1687               0.172079                False         schipperke
#
#      second_prediction_conf second_prediction_dog    third_prediction  \
# ...

# %%
twitter_archive_clean.first_prediction.value_counts()
# Out:
# golden_retriever               137
# Labrador_retriever              94
# Pembroke                        88
# Chihuahua                       78
# pug                             54
# chow                            41
# Samoyed                         40
# Pomeranian                      38
# toy_poodle                      37
# malamute                        29
# cocker_spaniel                  27
# French_bulldog                  26
# Chesapeake_Bay_retriever        23
# miniature_pinscher              21
# Siberian_husky                  20
# German_shepherd                 20
# seat_belt                       20
# Staffordshire_bullterrier       19
# Eskimo_dog                      18
# Shetland_sheepdog               18
# Maltese_dog                     18
# Cardigan                        17
# Shih-Tzu                        17
# beagle                          17
# Italian_greyhound               16
# Rottweiler                      16
# kuvasz                          15
# ...

# %%
twitter_archive_clean[twitter_archive_clean.first_prediction == 'golden_retriever'].head()
# Out:
#               tweet_id           timestamp  \
# 14  889531135344209921 2017-07-24 17:02:04
# 16  888917238123831296 2017-07-23 00:22:39
# 17  888804989199671297 2017-07-22 16:56:37
# 41  883482846933004288 2017-07-08 00:28:19
# 43  883117836046086144 2017-07-07 00:17:54
#
#                                                source  \
# 14  <a href="http://twitter.com/download/iphone" r...
# 16  <a href="http://twitter.com/download/iphone" r...
# 17  <a href="http://twitter.com/download/iphone" r...
# 41  <a href="http://twitter.com/download/iphone" r...
# 43  <a href="http://twitter.com/download/iphone" r...
#
#                                                  text  \
# 14  This is Stuart. He's sporting his favorite fan...
# 16  This is Jim. He found a fren. Taught him how t...
# 17  This is Zeke. He has a new stick. Very proud o...
# 41  This is Bella. She hopes her smile made you sm...
# 43  Please only send dogs. We don't rate mechanics...
#
# ...

# %% [markdown]
# ### Insights:
#
# * The highest value of rating is 14
# * Only 336 of the 2356 tweets had dog_stages
# * Of the tweets that had stages, pupper was the most, consisting about two thirds of the total
# * Of the tweets with Dog names, Obie's tweet seemed to have the highest number of retweets and favorites count
# * For the image predictions, over three-fourths of the first image predictions by the algorithm turned out to be dogs
# * Out of the correct first predictions, 'golden_retreiver' is the most predicted dog breed

# %% [markdown]
# ### Limitations:

# %% [markdown]
# * Some tweets lacked some information like dog names and dog stage
# * Most of the tweets lacked dog stage. Less than 25% of the tweets had dog stage
